# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import time
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
feature_cols = ['Sample_id','ad_id', 'Creation_time','Ad_material_size', 'Ad_Industry_Id', 'Commodity_type',
                            'Commodity_id','Ad_account_id','Delivery_time','Chose_People','Ad_bid']
test_df = pd.read_csv('testA/test_sample.dat', sep='\t', header=None,names=feature_cols)
test_df.head()
# Out:
#    Sample_id   ad_id  Creation_time  Ad_material_size  Ad_Industry_Id  \
# 0          1  394352     1529648412                34              84
# 1          2  585401     1553076190                40             221
# 2          3  419408     1553031394                30             122
# 3          4  405326     1553238836                64             136
# 4          5  578942     1541191585                34              12
#
#    Commodity_type  Commodity_id  Ad_account_id  \
# 0              13         29663          26657
# 1               1            -1           6262
# 2              13         32110          17436
# 3               1            -1          22359
# 4              13          6372          24082
#
#                                        Delivery_time  \
# 0  281474976645120,281474976645120,28147497664512...
# 1  281474976579587,281474976579587,28147497657958...
# 2  17592185782272,17592185782272,17592185782272,1...
# ...

# %%
#test_df = test_df.sort_values(['Creation_time'])

# %%
# 将时间戳改为时间
test_df['Creation_time'] = test_df['Creation_time'].apply(lambda x:time.strftime("%Y-%m-%d %H:%M:%S",time.localtime(x))) 
test_df.head(10)
# Out:
#    Sample_id   ad_id        Creation_time  Ad_material_size  Ad_Industry_Id  \
# 0          1  394352  2018-06-22 14:20:12                34              84
# 1          2  585401  2019-03-20 18:03:10                40             221
# 2          3  419408  2019-03-20 05:36:34                30             122
# 3          4  405326  2019-03-22 15:13:56                64             136
# 4          5  578942  2018-11-03 04:46:25                34              12
# 5          6  269774  2019-03-04 11:52:16                40             122
# 6          7  416368  2018-12-27 05:37:05                34              84
# 7          8  574309  2018-12-18 17:01:01                14              25
# 8          9  142702  2018-12-21 20:54:11                 1              50
# 9         10  255347  2019-03-11 14:52:22                40             122
#
#    Commodity_type  Commodity_id  Ad_account_id  \
# 0              13         29663          26657
# ...

# %%
test_df.to_csv('test_sample.csv', index=False)
